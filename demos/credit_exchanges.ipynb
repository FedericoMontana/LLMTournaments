# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os

from llmtournaments.games.credit_exchanges.base_objects import (
    GameConfig,
    LLMPlayer,
)
from llmtournaments.games.credit_exchanges.credit_exchanges_game import (
    CreditExchangeGame,
)
from llmtournaments.games.credit_exchanges.observers import ConsolePrinter
from llmtournaments.llm.generators.abacus_api import AbacusLLMInteraction

n_rounds = 3
initial_balance = 100
n_com_cycles = 3

abacus_key = os.getenv("ABACUSAI_API_KEY")

#  ["'ABACUS_DRACARYS'", "'ABACUS_SMAUG3'", "'CLAUDE_V3_5_HAIKU'", "'CLAUDE_V3_5_SONNET'", "'CLAUDE_V3_HAIKU'", "'CLAUDE_V3_OPUS'", "'CLAUDE_V3_SONNET'", "'GEMINI_1_5_FLASH'", "'GEMINI_1_5_PRO'", "'GEMINI_2_FLASH'", "'LLAMA3_1_405B'", "'LLAMA3_1_70B'", "'LLAMA3_1_8B'", "'LLAMA3_3_70B'", "'LLAMA3_LARGE_CHAT'", "'OPENAI_GPT3_5'", "'OPENAI_GPT3_5_TEXT'", "'OPENAI_GPT4'", "'OPENAI_GPT4O'", "'OPENAI_GPT4O_MINI'", "'OPENAI_GPT4_128K'", "'OPENAI_GPT4_128K_LATEST'", "'OPENAI_GPT4_32K'", "'QWEN_2_5_32B'", "'QWEN_2_5_72B'", "'QWQ_32B'", "'XAI_GROK'"]

player1 = LLMPlayer(
    llm=AbacusLLMInteraction(abacus_key, llm_name="CLAUDE_V3_5_SONNET", temperature=1),
    name="Claude",
)

player2 = LLMPlayer(
    llm=AbacusLLMInteraction(abacus_key, llm_name="LLAMA3_1_405B", temperature=1),
    name="Llama",
)

player3 = LLMPlayer(
    llm=AbacusLLMInteraction(abacus_key, llm_name="GEMINI_2_FLASH", temperature=1),
    name="Gemini",
)

# player4 = LLMPlayer(
#     llm=AbacusLLMInteraction(abacus_key, llm_name="OPENAI_GPT4O", temperature=1),
#     name="ChatGPT",
# )

# player5 = LLMPlayer(
#     llm=AbacusLLMInteraction(abacus_key, llm_name="QWEN_2_5_32B", temperature=1),
#     name="Qwen",
# )

# player6 = LLMPlayer(
#     llm=AbacusLLMInteraction(abacus_key, llm_name="XAI_GROK", temperature=1),
#     name="Grok",
# )

players = [player1, player2, player3]  # , player4, player5, player6]

gc = GameConfig(n_rounds, initial_balance, n_com_cycles)
printer = ConsolePrinter()

game = CreditExchangeGame(players, gc)

game.add_observer(printer)
game.run_game()
# Out:
# ────────────────────────────────────────
# Game Started
#
# Game Configuration:
# Players (3):
#    - Claude (Starting balance: 100 credits)
#    - Llama (Starting balance: 100 credits)
#    - Gemini (Starting balance: 100 credits)
#
# Total Rounds: 3
# Message Cycles per Round: 3
#
# Game Rules:
# - Players can send messages and make transactions each round
# - Transactions affect credit balances
# - Bonuses are awarded for cooperation
# - Rankings are updated per round
# - Final standings by total credits
#
#
#
# Round 1 Initiated
#
# Game Status:
# - Total Rounds: 3
# - Current Round: 1
# - Current Rankings (by balance):
#
#   1. Claude: 100 credits
#
#   2. Llama: 100 credits
#
#   3. Gemini: 100 credits
#
#
# REMEMBER: You are Claude.
#
# History of Rounds So Far:
#
# None, it is the first round.
#
#
# We are now running round 1:
#
# Messages you've sent or received this round (only visible to you and the sender/receiver, displayed in chronological order with the newest messages at the bottom):
#
#   None yet
#
#
# It's time to send a message (optional). Important facts to consider for your strategy:
# - In this round, you have 2 message(s) left after this one
# - There are 2 rounds remaining after this one
# - Use this opportunity to influence other players' decisions
#
# Message Rules:
# 1. You can send a message to ONE player only
# 2. Respond with a JSON formatted string, containing 'recipient' and 'message', or type 'SKIP'
#    Example: {"recipient": "player_name", "message": "your message"}
#
# Your message will be rejected if you use anything other than a JSON formatted string or 'SKIP'. Be accurate.
# Your message:
# ---------------------------------------------------------------------------
# ApiException                              Traceback (most recent call last)
# Cell In[3], line 59
#      56 game = CreditExchangeGame(players, gc)
#      58 game.add_observer(printer)
# ---> 59 game.run_game()
#
# File ~/codes/LLMTournaments/llmtournaments/games/credit_exchanges/credit_exchanges_game.py:280, in CreditExchangeGame.run_game(self)
#     277 self.notify_observers("on_game_start", self.game_config, self.game_state)
#     279 for _ in range(self.game_config.total_rounds):
# --> 280     self._conduct_round()
#     282 final_balances = {
#     283     player.name: self.game_state.get_balance(player)
#     284     for player in self.game_state.players
#     285 }
#     287 self.notify_observers("on_game_end", self.game_state)
#
# File ~/codes/LLMTournaments/llmtournaments/games/credit_exchanges/credit_exchanges_game.py:258, in CreditExchangeGame._conduct_round(self)
#     255 round_number = self.game_state.get_current_round()
#     256 self.notify_observers("on_round_start", self.game_state, round_number)
# --> 258 ongoing_round_messages = self._conduct_messaging_phase()
#     259 transactions = self._conduct_transaction_phase(ongoing_round_messages)
#     261 self.notify_observers(
#     262     "on_transactions_processed", self.game_state, transactions
#     263 )
#
# File ~/codes/LLMTournaments/llmtournaments/games/credit_exchanges/credit_exchanges_game.py:158, in CreditExchangeGame._conduct_messaging_phase(self)
#     155     print(prompt)
#     156     print("---------------------------")
# --> 158 response = player.llm(prompt).response
#     159 recipient_player, message = None, response  # default for "SKIP" cases
#     161 if response.strip().upper() != "SKIP":
#
# File ~/codes/LLMTournaments/llmtournaments/llm/llm_interaction_base.py:129, in LLMInteractionBase.__call__(self, user_input, **kwargs)
#     126 try:
#     127     logger.debug(f"Sending to the model: {self._conversation}")
# --> 129     response = self._generate_response(**kwargs)
#     131     generation_time = time.perf_counter() - start_time
#     132     logger.debug(
#     133         f"Generated response ({generation_time:.4f} seconds): '{response}'"
#     134     )
#
# File ~/codes/LLMTournaments/llmtournaments/llm/generators/abacus_api.py:72, in AbacusLLMInteraction._generate_response(self, **kwargs)
#      69 logger.debug(f"Evaluate prompt arguments: {evaluate_prompt_args}")
#      71 # Call the evaluate_prompt method
# ---> 72 response = self.client.evaluate_prompt(**evaluate_prompt_args)
#      74 # The response is in response['output']
#      75 return response.content
#
# File ~/codes/LLMTournaments/.venv/lib/python3.13/site-packages/abacusai/client.py:8662, in ApiClient.evaluate_prompt(self, prompt, system_message, llm_name, max_tokens, temperature, messages, response_type, json_response_schema, stop_sequences, top_p)
#    8645 def evaluate_prompt(self, prompt: str = None, system_message: str = None, llm_name: Union[LLMName, str] = None, max_tokens: int = None, temperature: float = 0.0, messages: list = None, response_type: str = None, json_response_schema: dict = None, stop_sequences: List = None, top_p: float = None) -> LlmResponse:
#    8646     """Generate response to the prompt using the specified model.
#    8647
#    8648     Args:
#    (...)
#    8660     Returns:
#    8661         LlmResponse: The response from the model, raw text and parsed components."""
# -> 8662     return self._proxy_request('EvaluatePrompt', 'POST', query_params={}, body={'prompt': prompt, 'systemMessage': system_message, 'llmName': llm_name, 'maxTokens': max_tokens, 'temperature': temperature, 'messages': messages, 'responseType': response_type, 'jsonResponseSchema': json_response_schema, 'stopSequences': stop_sequences, 'topP': top_p}, parse_type=LlmResponse)
#
# File ~/codes/LLMTournaments/.venv/lib/python3.13/site-packages/abacusai/client.py:889, in BaseApiClient._proxy_request(self, name, method, query_params, body, data, files, parse_type, is_sync, streamable_response)
#     887 error_message = error_json.get('error') or 'Unknown error'
#     888 error_type = error_json.get('errorType')
# --> 889 raise _ApiExceptionFactory.from_response(
#     890     error_message, status_code, error_type, request_id)
#
# ApiException: ApiException(500): Internal server error

# %%
from llmtournaments.games.credit_exchanges.base_objects import (
    GameConfig,
    LLMPlayer,
)
from llmtournaments.games.credit_exchanges.credit_exchanges_game import (
    CreditExchangeGame,
)
from llmtournaments.games.credit_exchanges.observers import ConsolePrinter
from llmtournaments.llm.generators.dummy_llm_03 import (
    DummyLLMInteractionForCreditExchanges,
)

num_players = 3
threshold = 500
initial_balance = 1000
rounds = 2

dummy_llmA = LLMPlayer(
    llm=DummyLLMInteractionForCreditExchanges("A", ["B", "C"], 10), name="A"
)
dummy_llmB = LLMPlayer(
    llm=DummyLLMInteractionForCreditExchanges("B", ["A", "C"], 10), name="B"
)
dummy_llmC = LLMPlayer(
    llm=DummyLLMInteractionForCreditExchanges("C", ["A", "B"], 10), name="C"
)

players = [dummy_llmA, dummy_llmB, dummy_llmC]

gc = GameConfig(4, 10, 3)
lo = ConsolePrinter()


game = CreditExchangeGame(players, gc)
game.add_observer(lo)
game.run_game()
# Out:
# ────────────────────────────────────────
# Game Started
#
# Game Configuration:
# Players (3):
#    - A (Starting balance: 10 credits)
#    - B (Starting balance: 10 credits)
#    - C (Starting balance: 10 credits)
#
# Total Rounds: 4
# Message Cycles per Round: 3
#
# Game Rules:
# - Players can send messages and make transactions each round
# - Transactions affect credit balances
# - Bonuses are awarded for cooperation
# - Rankings are updated per round
# - Final standings by total credits
#
#
#
# Round 1 Initiated
# Message: A -> No Recipient: SKIP
#
# ------Message B -----
# ++++
# []
# ++++
#
# Game Status:
# - Total Rounds: 4
# - Current Round: 1
# - Current Rankings (by balance):
#
#   1. A: 10 credits
#
#   2. B: 10 credits
#
#   3. C: 10 credits
#
#
# REMEMBER: You are B.
#
# History of Rounds So Far:
#
# None, it is the first round.
#
#
# We are now running round 1:
#
# Messages you've sent or received this round (only visible to you and the sender/receiver, displayed in chronological order with the newest messages at the bottom):
#
#   None yet
#
#
# It's time to send a message (optional). Important facts to consider for your strategy:
# - In this round, you have 2 message(s) left after this one
# - There are 3 rounds remaining after this one
# - Use this opportunity to influence other players' decisions
#
# Message Rules:
# 1. You can send a message to ONE player only
# 2. Respond with a JSON formatted string, containing 'recipient' and 'message', or type 'SKIP'
#    Example: {"recipient": "player_name", "message": "your message"}
#
# Your message will be rejected if you use anything other than a JSON formatted string or 'SKIP'. Be accurate.
# Your message:
# ---------------------------
# Message: B -> C: Let's maximize our profits together!
# Message: C -> B: How about a truce?
# Message: A -> C: How about a truce?
# Message: C -> A: Watch out for the big moves!
#
# ------Message B -----
# ++++
# [(LLMPlayer(llm=<llmtournaments.llm.generators.dummy_llm_03.DummyLLMInteractionForCreditExchanges object at 0x13786dbd0>, name='B'), LLMPlayer(llm=<llmtournaments.llm.generators.dummy_llm_03.DummyLLMInteractionForCreditExchanges object at 0x13786de50>, name='C'), "Let's maximize our profits together!"), (LLMPlayer(llm=<llmtournaments.llm.generators.dummy_llm_03.DummyLLMInteractionForCreditExchanges object at 0x13786de50>, name='C'), LLMPlayer(llm=<llmtournaments.llm.generators.dummy_llm_03.DummyLLMInteractionForCreditExchanges object at 0x13786dbd0>, name='B'), 'How about a truce?'), (LLMPlayer(llm=<llmtournaments.llm.generators.dummy_llm_03.DummyLLMInteractionForCreditExchanges object at 0x132772650>, name='A'), LLMPlayer(llm=<llmtournaments.llm.generators.dummy_llm_03.DummyLLMInteractionForCreditExchanges object at 0x13786de50>, name='C'), 'How about a truce?'), (LLMPlayer(llm=<llmtournaments.llm.generators.dummy_llm_03.DummyLLMInteractionForCreditExchanges object at 0x13786de50>, name='C'), LLMPlayer(llm=<llmtournaments.llm.generators.dummy_llm_03.DummyLLMInteractionForCreditExchanges object at 0x132772650>, name='A'), 'Watch out for the big moves!')]
# ++++
#
# Game Status:
# - Total Rounds: 4
# - Current Round: 1
# - Current Rankings (by balance):
#
#   1. A: 10 credits
#
#   2. B: 10 credits
#
#   3. C: 10 credits
#
#
# REMEMBER: You are B.
#
# History of Rounds So Far:
#
# None, it is the first round.
#
#
# We are now running round 1:
#
# Messages you've sent or received this round (only visible to you and the sender/receiver, displayed in chronological order with the newest messages at the bottom):
#
#
#   - B sent to C: 'Let's maximize our profits together!'
#
#   - C sent to B: 'How about a truce?'
#
#
#
# It's time to send a message (optional). Important facts to consider for your strategy:
# - In this round, you have 1 message(s) left after this one
# - There are 3 rounds remaining after this one
# - Use this opportunity to influence other players' decisions
#
# Message Rules:
# 1. You can send a message to ONE player only
# 2. Respond with a JSON formatted string, containing 'recipient' and 'message', or type 'SKIP'
#    Example: {"recipient": "player_name", "message": "your message"}
#
# Your message will be rejected if you use anything other than a JSON formatted string or 'SKIP'. Be accurate.
# Your message:
# ---------------------------
# Message: B -> C: How about a truce?
# Message: C -> B: Watch out for the big moves!
# Message: A -> B: Watch out for the big moves!
#
# ------Message B -----
# ++++
# [(LLMPlayer(llm=<llmtournaments.llm.generators.dummy_llm_03.DummyLLMInteractionForCreditExchanges object at 0x13786dbd0>, name='B'), LLMPlayer(llm=<llmtournaments.llm.generators.dummy_llm_03.DummyLLMInteractionForCreditExchanges object at 0x13786de50>, name='C'), "Let's maximize our profits together!"), (LLMPlayer(llm=<llmtournaments.llm.generators.dummy_llm_03.DummyLLMInteractionForCreditExchanges object at 0x13786de50>, name='C'), LLMPlayer(llm=<llmtournaments.llm.generators.dummy_llm_03.DummyLLMInteractionForCreditExchanges object at 0x13786dbd0>, name='B'), 'How about a truce?'), (LLMPlayer(llm=<llmtournaments.llm.generators.dummy_llm_03.DummyLLMInteractionForCreditExchanges object at 0x132772650>, name='A'), LLMPlayer(llm=<llmtournaments.llm.generators.dummy_llm_03.DummyLLMInteractionForCreditExchanges object at 0x13786de50>, name='C'), 'How about a truce?'), (LLMPlayer(llm=<llmtournaments.llm.generators.dummy_llm_03.DummyLLMInteractionForCreditExchanges object at 0x13786de50>, name='C'), LLMPlayer(llm=<llmtournaments.llm.generators.dummy_llm_03.DummyLLMInteractionForCreditExchanges object at 0x132772650>, name='A'), 'Watch out for the big moves!'), (LLMPlayer(llm=<llmtournaments.llm.generators.dummy_llm_03.DummyLLMInteractionForCreditExchanges object at 0x13786dbd0>, name='B'), LLMPlayer(llm=<llmtournaments.llm.generators.dummy_llm_03.DummyLLMInteractionForCreditExchanges object at 0x13786de50>, name='C'), 'How about a truce?'), (LLMPlayer(llm=<llmtournaments.llm.generators.dummy_llm_03.DummyLLMInteractionForCreditExchanges object at 0x13786de50>, name='C'), LLMPlayer(llm=<llmtournaments.llm.generators.dummy_llm_03.DummyLLMInteractionForCreditExchanges object at 0x13786dbd0>, name='B'), 'Watch out for the big moves!'), (LLMPlayer(llm=<llmtournaments.llm.generators.dummy_llm_03.DummyLLMInteractionForCreditExchanges object at 0x132772650>, name='A'), LLMPlayer(llm=<llmtournaments.llm.generators.dummy_llm_03.DummyLLMInteractionForCreditExchanges object at 0x13786dbd0>, name='B'), 'Watch out for the big moves!')]
# ++++
#
# Game Status:
# - Total Rounds: 4
# - Current Round: 1
# - Current Rankings (by balance):
#
#   1. A: 10 credits
#
#   2. B: 10 credits
#
#   3. C: 10 credits
#
#
# REMEMBER: You are B.
#
# History of Rounds So Far:
#
# None, it is the first round.
#
#
# We are now running round 1:
#
# Messages you've sent or received this round (only visible to you and the sender/receiver, displayed in chronological order with the newest messages at the bottom):
#
#
#   - B sent to C: 'Let's maximize our profits together!'
#
#   - C sent to B: 'How about a truce?'
#
#   - B sent to C: 'How about a truce?'
#
#   - C sent to B: 'Watch out for the big moves!'
#
#   - A sent to B: 'Watch out for the big moves!'
#
#
#
# It's time to send a message (optional). Important facts to consider for your strategy:
# - In this round, you have 0 message(s) left after this one
# - There are 3 rounds remaining after this one
# - Use this opportunity to influence other players' decisions
#
# Message Rules:
# 1. You can send a message to ONE player only
# 2. Respond with a JSON formatted string, containing 'recipient' and 'message', or type 'SKIP'
#    Example: {"recipient": "player_name", "message": "your message"}
#
# Your message will be rejected if you use anything other than a JSON formatted string or 'SKIP'. Be accurate.
# Your message:
# ---------------------------
# Message: B -> C: Let's collaborate this round.
#
# Message Phase Concluded.
# Transaction: A sent 3 credits to B
# Transaction: A sent 4 credits to C
#
# ------Transaction B -----
#
# Game Status:
# - Total Rounds: 4
# - Current Round: 1
# - Current Rankings (by balance):
#
#   1. A: 10 credits
#
#   2. B: 10 credits
#
#   3. C: 10 credits
#
#
# REMEMBER: You are B.
#
# History of Rounds So Far:
#
# None, it is the first round.
#
#
# We are now running round 1:
#
# Messages you've sent or received this round (only visible to you and the sender/receiver, displayed in chronological order with the newest messages at the bottom):
#
#
#   - B sent to C: 'Let's maximize our profits together!'
#
#   - C sent to B: 'How about a truce?'
#
#   - B sent to C: 'How about a truce?'
#
#   - C sent to B: 'Watch out for the big moves!'
#
#   - A sent to B: 'Watch out for the big moves!'
#
#   - B sent to C: 'Let's collaborate this round.'
#
#
#
# The messaging phase is complete. It is time to place your transactions. Your current balance is 10 credits.
# There are 3 rounds remaining after this one. Carefully evaluate your strategy of giving credits considering:
# - Remaining rounds
# - Current rankings
# - Your balance
# - Other players' past rounds messages and final strategies, and current's round messages
#
# Transaction Rules:
# 1. Specify your transactions with a JSON formatted string or type 'SKIP' to pass
#    Example: {"player_name": amount, "player_name2": amount2, ... }
#    You can send transactions to one, multiple, or all players - you have only one attempt
#
# 2. Your transactions WILL BE REJECTED if:
#    - You use anything other than a JSON formatted string or 'SKIP'
#    - You attempt to give more credits than your current balance (10)
#
# Your response:
# ---------------------------
# Transaction: B sent 2 credits to A
# Transaction: B sent 6 credits to C
# Transaction: C sent 3 credits to A
#
# Transaction Phase Concluded.
#
# Transaction Matrix - Round 1
# ╒════════╤═════╤═════╤═════╕
# │   TO   │  A  │  B  │  C  │
# ╞════════╪═════╪═════╪═════╡
# │ FROM A │  —  │  3  │  4  │
# ├────────┼─────┼─────┼─────┤
# │ FROM B │  2  │  —  │  6  │
# ├────────┼─────┼─────┼─────┤
# │ FROM C │  3  │  0  │  —  │
# ╘════════╧═════╧═════╧═════╛
#
# Round Summary:
# ------------------  ----------
# Total Transactions  18 credits
# Active Players      3
# ------------------  ----------
# Bonus Awarded: A and B received 2 credits.
# Bonus Awarded: A and C received 3 credits.
#
# Current Rankings:
# ╒════════╤══════════╤════════════╕
# │   Rank │  Player  │  Balance   │
# ╞════════╪══════════╪════════════╡
# │      1 │    C     │ 20 credits │
# ├────────┼──────────┼────────────┤
# │      2 │    A     │ 13 credits │
# ├────────┼──────────┼────────────┤
# │      3 │    B     │ 7 credits  │
# ╘════════╧══════════╧════════════╛
#
#
# Round 2 Initiated
#
# ------Message B -----
# ++++
# []
# ++++
#
# Game Status:
# - Total Rounds: 4
# - Current Round: 2
# - Current Rankings (by balance):
#
#   1. C: 20 credits
#
#   2. A: 13 credits
#
#   3. B: 7 credits
#
#
# REMEMBER: You are B.
#
# History of Rounds So Far:
#
#
# Round 1:
# Messages you've sent or received (visible only to you and the sender/receiver, displayed in chronological order with the newest messages at the bottom):
#
#
#   - B sent to C: 'Let's maximize our profits together!'
#
#   - C sent to B: 'How about a truce?'
#
#   - B sent to C: 'How about a truce?'
#
#   - C sent to B: 'Watch out for the big moves!'
#
#   - A sent to B: 'Watch out for the big moves!'
#
#   - B sent to C: 'Let's collaborate this round.'
#
#
# Following are the transactions made by all players after the messaging phase concluded (this is public information from past rounds, visible now to every player):
#
#
#   - A sent 3 credits to B
#
#   - A sent 4 credits to C
#
#
#
#   - B sent 2 credits to A
#
#   - B sent 6 credits to C
#
#
#
#   - C sent 3 credits to A
#
#
#
#
#
# We are now running round 2:
#
# Messages you've sent or received this round (only visible to you and the sender/receiver, displayed in chronological order with the newest messages at the bottom):
#
#   None yet
#
#
# It's time to send a message (optional). Important facts to consider for your strategy:
# - In this round, you have 2 message(s) left after this one
# - There are 2 rounds remaining after this one
# - Use this opportunity to influence other players' decisions
#
# Message Rules:
# 1. You can send a message to ONE player only
# 2. Respond with a JSON formatted string, containing 'recipient' and 'message', or type 'SKIP'
#    Example: {"recipient": "player_name", "message": "your message"}
#
# Your message will be rejected if you use anything other than a JSON formatted string or 'SKIP'. Be accurate.
# Your message:
# ---------------------------
# Message: B -> A: Watch out for the big moves!
# Message: C -> A: Let's maximize our profits together!
# Message: A -> C: Let's maximize our profits together!
#
# ------Message B -----
# ++++
# [(LLMPlayer(llm=<llmtournaments.llm.generators.dummy_llm_03.DummyLLMInteractionForCreditExchanges object at 0x13786dbd0>, name='B'), LLMPlayer(llm=<llmtournaments.llm.generators.dummy_llm_03.DummyLLMInteractionForCreditExchanges object at 0x132772650>, name='A'), 'Watch out for the big moves!'), (LLMPlayer(llm=<llmtournaments.llm.generators.dummy_llm_03.DummyLLMInteractionForCreditExchanges object at 0x13786de50>, name='C'), LLMPlayer(llm=<llmtournaments.llm.generators.dummy_llm_03.DummyLLMInteractionForCreditExchanges object at 0x132772650>, name='A'), "Let's maximize our profits together!"), (LLMPlayer(llm=<llmtournaments.llm.generators.dummy_llm_03.DummyLLMInteractionForCreditExchanges object at 0x132772650>, name='A'), LLMPlayer(llm=<llmtournaments.llm.generators.dummy_llm_03.DummyLLMInteractionForCreditExchanges object at 0x13786de50>, name='C'), "Let's maximize our profits together!")]
# ++++
#
# Game Status:
# - Total Rounds: 4
# - Current Round: 2
# - Current Rankings (by balance):
#
#   1. C: 20 credits
#
#   2. A: 13 credits
#
#   3. B: 7 credits
#
#
# REMEMBER: You are B.
#
# History of Rounds So Far:
#
#
# Round 1:
# Messages you've sent or received (visible only to you and the sender/receiver, displayed in chronological order with the newest messages at the bottom):
#
#
#   - B sent to C: 'Let's maximize our profits together!'
#
#   - C sent to B: 'How about a truce?'
#
#   - B sent to C: 'How about a truce?'
#
#   - C sent to B: 'Watch out for the big moves!'
#
#   - A sent to B: 'Watch out for the big moves!'
#
#   - B sent to C: 'Let's collaborate this round.'
#
#
# Following are the transactions made by all players after the messaging phase concluded (this is public information from past rounds, visible now to every player):
#
#
#   - A sent 3 credits to B
#
#   - A sent 4 credits to C
#
#
#
#   - B sent 2 credits to A
#
#   - B sent 6 credits to C
#
#
#
#   - C sent 3 credits to A
#
#
#
#
#
# We are now running round 2:
#
# Messages you've sent or received this round (only visible to you and the sender/receiver, displayed in chronological order with the newest messages at the bottom):
#
#
#   - B sent to A: 'Watch out for the big moves!'
#
#
#
# It's time to send a message (optional). Important facts to consider for your strategy:
# - In this round, you have 1 message(s) left after this one
# - There are 2 rounds remaining after this one
# - Use this opportunity to influence other players' decisions
#
# Message Rules:
# 1. You can send a message to ONE player only
# 2. Respond with a JSON formatted string, containing 'recipient' and 'message', or type 'SKIP'
#    Example: {"recipient": "player_name", "message": "your message"}
#
# Your message will be rejected if you use anything other than a JSON formatted string or 'SKIP'. Be accurate.
# Your message:
# ---------------------------
# Message: B -> No Recipient: SKIP
# Message: A -> B: Let's collaborate this round.
# Message: C -> A: Let's maximize our profits together!
# Message: C -> A: How about a truce?
# Message: A -> C: Let's maximize our profits together!
#
# ------Message B -----
# ++++
# [(LLMPlayer(llm=<llmtournaments.llm.generators.dummy_llm_03.DummyLLMInteractionForCreditExchanges object at 0x13786dbd0>, name='B'), LLMPlayer(llm=<llmtournaments.llm.generators.dummy_llm_03.DummyLLMInteractionForCreditExchanges object at 0x132772650>, name='A'), 'Watch out for the big moves!'), (LLMPlayer(llm=<llmtournaments.llm.generators.dummy_llm_03.DummyLLMInteractionForCreditExchanges object at 0x13786de50>, name='C'), LLMPlayer(llm=<llmtournaments.llm.generators.dummy_llm_03.DummyLLMInteractionForCreditExchanges object at 0x132772650>, name='A'), "Let's maximize our profits together!"), (LLMPlayer(llm=<llmtournaments.llm.generators.dummy_llm_03.DummyLLMInteractionForCreditExchanges object at 0x132772650>, name='A'), LLMPlayer(llm=<llmtournaments.llm.generators.dummy_llm_03.DummyLLMInteractionForCreditExchanges object at 0x13786de50>, name='C'), "Let's maximize our profits together!"), (LLMPlayer(llm=<llmtournaments.llm.generators.dummy_llm_03.DummyLLMInteractionForCreditExchanges object at 0x132772650>, name='A'), LLMPlayer(llm=<llmtournaments.llm.generators.dummy_llm_03.DummyLLMInteractionForCreditExchanges object at 0x13786dbd0>, name='B'), "Let's collaborate this round."), (LLMPlayer(llm=<llmtournaments.llm.generators.dummy_llm_03.DummyLLMInteractionForCreditExchanges object at 0x13786de50>, name='C'), LLMPlayer(llm=<llmtournaments.llm.generators.dummy_llm_03.DummyLLMInteractionForCreditExchanges object at 0x132772650>, name='A'), "Let's maximize our profits together!"), (LLMPlayer(llm=<llmtournaments.llm.generators.dummy_llm_03.DummyLLMInteractionForCreditExchanges object at 0x13786de50>, name='C'), LLMPlayer(llm=<llmtournaments.llm.generators.dummy_llm_03.DummyLLMInteractionForCreditExchanges object at 0x132772650>, name='A'), 'How about a truce?'), (LLMPlayer(llm=<llmtournaments.llm.generators.dummy_llm_03.DummyLLMInteractionForCreditExchanges object at 0x132772650>, name='A'), LLMPlayer(llm=<llmtournaments.llm.generators.dummy_llm_03.DummyLLMInteractionForCreditExchanges object at 0x13786de50>, name='C'), "Let's maximize our profits together!")]
# ++++
#
# Game Status:
# - Total Rounds: 4
# - Current Round: 2
# - Current Rankings (by balance):
#
#   1. C: 20 credits
#
#   2. A: 13 credits
#
#   3. B: 7 credits
#
#
# REMEMBER: You are B.
#
# History of Rounds So Far:
#
#
# Round 1:
# Messages you've sent or received (visible only to you and the sender/receiver, displayed in chronological order with the newest messages at the bottom):
#
#
#   - B sent to C: 'Let's maximize our profits together!'
#
#   - C sent to B: 'How about a truce?'
#
#   - B sent to C: 'How about a truce?'
#
#   - C sent to B: 'Watch out for the big moves!'
#
#   - A sent to B: 'Watch out for the big moves!'
#
#   - B sent to C: 'Let's collaborate this round.'
#
#
# Following are the transactions made by all players after the messaging phase concluded (this is public information from past rounds, visible now to every player):
#
#
#   - A sent 3 credits to B
#
#   - A sent 4 credits to C
#
#
#
#   - B sent 2 credits to A
#
#   - B sent 6 credits to C
#
#
#
#   - C sent 3 credits to A
#
#
#
#
#
# We are now running round 2:
#
# Messages you've sent or received this round (only visible to you and the sender/receiver, displayed in chronological order with the newest messages at the bottom):
#
#
#   - B sent to A: 'Watch out for the big moves!'
#
#   - A sent to B: 'Let's collaborate this round.'
#
#
#
# It's time to send a message (optional). Important facts to consider for your strategy:
# - In this round, you have 0 message(s) left after this one
# - There are 2 rounds remaining after this one
# - Use this opportunity to influence other players' decisions
#
# Message Rules:
# 1. You can send a message to ONE player only
# 2. Respond with a JSON formatted string, containing 'recipient' and 'message', or type 'SKIP'
#    Example: {"recipient": "player_name", "message": "your message"}
#
# Your message will be rejected if you use anything other than a JSON formatted string or 'SKIP'. Be accurate.
# Your message:
# ---------------------------
# Message: B -> A: How about a truce?
#
# Message Phase Concluded.
# Transaction: A sent 1 credits to B
#
# ------Transaction B -----
#
# Game Status:
# - Total Rounds: 4
# - Current Round: 2
# - Current Rankings (by balance):
#
#   1. C: 20 credits
#
#   2. A: 13 credits
#
#   3. B: 7 credits
#
#
# REMEMBER: You are B.
#
# History of Rounds So Far:
#
#
# Round 1:
# Messages you've sent or received (visible only to you and the sender/receiver, displayed in chronological order with the newest messages at the bottom):
#
#
#   - B sent to C: 'Let's maximize our profits together!'
#
#   - C sent to B: 'How about a truce?'
#
#   - B sent to C: 'How about a truce?'
#
#   - C sent to B: 'Watch out for the big moves!'
#
#   - A sent to B: 'Watch out for the big moves!'
#
#   - B sent to C: 'Let's collaborate this round.'
#
#
# Following are the transactions made by all players after the messaging phase concluded (this is public information from past rounds, visible now to every player):
#
#
#   - A sent 3 credits to B
#
#   - A sent 4 credits to C
#
#
#
#   - B sent 2 credits to A
#
#   - B sent 6 credits to C
#
#
#
#   - C sent 3 credits to A
#
#
#
#
#
# We are now running round 2:
#
# Messages you've sent or received this round (only visible to you and the sender/receiver, displayed in chronological order with the newest messages at the bottom):
#
#
#   - B sent to A: 'Watch out for the big moves!'
#
#   - A sent to B: 'Let's collaborate this round.'
#
#   - B sent to A: 'How about a truce?'
#
#
#
# The messaging phase is complete. It is time to place your transactions. Your current balance is 7 credits.
# There are 2 rounds remaining after this one. Carefully evaluate your strategy of giving credits considering:
# - Remaining rounds
# - Current rankings
# - Your balance
# - Other players' past rounds messages and final strategies, and current's round messages
#
# Transaction Rules:
# 1. Specify your transactions with a JSON formatted string or type 'SKIP' to pass
#    Example: {"player_name": amount, "player_name2": amount2, ... }
#    You can send transactions to one, multiple, or all players - you have only one attempt
#
# 2. Your transactions WILL BE REJECTED if:
#    - You use anything other than a JSON formatted string or 'SKIP'
#    - You attempt to give more credits than your current balance (7)
#
# Your response:
# ---------------------------
# ERROR:llmtournaments.games.credit_exchanges.credit_exchanges_game:Transaction rejected: B attempted to send 8 credits but only has 7
# Transaction: C sent 10 credits to B
#
#
# Transaction Phase Concluded.
#
# Transaction Matrix - Round 2
# ╒════════╤═════╤═════╤═════╕
# │   TO   │  A  │  B  │  C  │
# ╞════════╪═════╪═════╪═════╡
# │ FROM A │  —  │  1  │  0  │
# ├────────┼─────┼─────┼─────┤
# │ FROM B │  0  │  —  │  0  │
# ├────────┼─────┼─────┼─────┤
# │ FROM C │  0  │ 10  │  —  │
# ╘════════╧═════╧═════╧═════╛
#
# Round Summary:
# ------------------  ----------
# Total Transactions  11 credits
# Active Players      3
# ------------------  ----------
#
# Current Rankings:
# ╒════════╤══════════╤════════════╕
# │   Rank │  Player  │  Balance   │
# ╞════════╪══════════╪════════════╡
# │      1 │    B     │ 18 credits │
# ├────────┼──────────┼────────────┤
# │      2 │    A     │ 12 credits │
# ├────────┼──────────┼────────────┤
# │      3 │    C     │ 10 credits │
# ╘════════╧══════════╧════════════╛
#
#
# Round 3 Initiated
# Message: A -> C: How about a truce?

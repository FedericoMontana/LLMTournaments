# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os

from llmtournaments.games.credit_exchanges.base_objects import (
    GameConfig,
    LLMPlayer,
)
from llmtournaments.games.credit_exchanges.credit_exchanges_game import (
    CreditExchangeGame,
)
from llmtournaments.games.credit_exchanges.observers import ConsolePrinter
from llmtournaments.llm.generators.abacus_api import AbacusLLMInteraction

n_rounds = 10
initial_balance = 100
n_com_cycles = 2

abacus_key = os.getenv("ABACUSAI_API_KEY")

#  ["'ABACUS_DRACARYS'", "'ABACUS_SMAUG3'", "'CLAUDE_V3_5_HAIKU'", "'CLAUDE_V3_5_SONNET'", "'CLAUDE_V3_HAIKU'", "'CLAUDE_V3_OPUS'", "'CLAUDE_V3_SONNET'", "'GEMINI_1_5_FLASH'", "'GEMINI_1_5_PRO'", "'GEMINI_2_FLASH'", "'LLAMA3_1_405B'", "'LLAMA3_1_70B'", "'LLAMA3_1_8B'", "'LLAMA3_3_70B'", "'LLAMA3_LARGE_CHAT'", "'OPENAI_GPT3_5'", "'OPENAI_GPT3_5_TEXT'", "'OPENAI_GPT4'", "'OPENAI_GPT4O'", "'OPENAI_GPT4O_MINI'", "'OPENAI_GPT4_128K'", "'OPENAI_GPT4_128K_LATEST'", "'OPENAI_GPT4_32K'", "'QWEN_2_5_32B'", "'QWEN_2_5_72B'", "'QWQ_32B'", "'XAI_GROK'"]

player1 = LLMPlayer(
    llm=AbacusLLMInteraction(abacus_key, llm_name="CLAUDE_V3_5_SONNET", temperature=1),
    name="Claude",
)

player2 = LLMPlayer(
    llm=AbacusLLMInteraction(abacus_key, llm_name="LLAMA3_1_405B", temperature=1),
    name="Llama",
)

player3 = LLMPlayer(
    llm=AbacusLLMInteraction(abacus_key, llm_name="GEMINI_2_FLASH", temperature=1),
    name="Gemini",
)

player4 = LLMPlayer(
    llm=AbacusLLMInteraction(abacus_key, llm_name="OPENAI_GPT4O", temperature=1),
    name="ChatGPT",
)

player5 = LLMPlayer(
    llm=AbacusLLMInteraction(abacus_key, llm_name="QWEN_2_5_32B", temperature=1),
    name="Qwen",
)

player6 = LLMPlayer(
    llm=AbacusLLMInteraction(abacus_key, llm_name="XAI_GROK", temperature=1),
    name="Grok",
)

players = [player1, player2, player3, player4, player5]

gc = GameConfig(n_rounds, initial_balance, n_com_cycles)
printer = ConsolePrinter()

game = CreditExchangeGame(players, gc)

game.add_observer(printer)
game.run_game()
# Out:
# /Users/federico/codes/LLMTournaments/.venv/lib/python3.13/site-packages/abacusai/client.py:657: UserWarning: A new version of the Abacus.AI library is available
#   warnings.warn(
# /Users/federico/codes/LLMTournaments/.venv/lib/python3.13/site-packages/abacusai/client.py:659: UserWarning: Current Version: 1.4.15 -> New Version: 1.4.20
#   warnings.warn(
# ──────────────────────────────────────────────────
# 🎮 GAME STARTED 🎮
# ──────────────────────────────────────────────────
#
# 📋 Game Configuration:
# Players (5):
#    • Claude (Starting balance: 100 credits)
#    • Llama (Starting balance: 100 credits)
#    • Gemini (Starting balance: 100 credits)
#    • ChatGPT (Starting balance: 100 credits)
#    • Qwen (Starting balance: 100 credits)
#
# Total Rounds: 10
#
# Total Message Cycles per round: 2
#
# 🎯 Game Rules:
# • Players can send messages and make transactions each round
# • Transactions between players affect their credit balance
# • Bonuses are awarded for successful cooperation
# • Rankings are updated after each round
# • Final standings determined by total credits
# ──────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────
# 📍 ROUND 1 📍
# ──────────────────────────────────────────────────
# 💬 Llama → Claude: Hello, I was thinking we could form an alliance for the first few rounds to see how things play out. We could mutually exchange credits to gain a bonus and establish a lead.
# 💬 Gemini → Claude: Let's cooperate. I'll send you 10 credits this round. If you send me 10 back, we both get a 10 credit bonus. We can continue this strategy in the coming rounds to build a strong lead.
# 💬 Claude → Gemini: Thank you for the offer. I accept your proposal to exchange 10 credits each. This mutual cooperation will benefit us both with the bonus. Let's proceed with this plan.
# 💬 Qwen → Claude: Hi Claude, let's discuss a strategic alliance. With combined resources, we can potentially outmaneuver the others. What do you think? Let's aim for mutual transfers and bonuses to strengthen our positions.
# 💬 ChatGPT → Gemini: Let's team up to maximize our credits. I'll send you 10 credits if you send me 10 credits in return. We both get a bonus this way. Deal?
# 💬 Claude → Llama: I appreciate your offer for an alliance. I'm already planning a small exchange with Gemini this round to test cooperation. However, I'm interested in working with you in future rounds - perhaps we can establish a stronger partnership starting next round?
# 💬 Qwen → Gemini: Hey Gemini, I noticed we both have the same starting balance. What do you think about forming an alliance? Combined, we could negotiate better deals with other players and maximize our credits. What do you say?
# 💬 Llama → Gemini: I see you're cooperating with Claude this round. I'd be interested in discussing potential future alliances with you as well. Perhaps we can find mutually beneficial opportunities in the coming rounds.
# 💬 Gemini → Llama: I'm open to discussing future alliances after this round.  Let's see how the initial exchanges play out first. It's important to evaluate trustworthiness early in the game.
# 💬 ChatGPT → Claude: Hey Claude, let's help each other out. I'll send you 10 credits if you send me 10 credits in return. We'll both get a bonus as a result. Let me know if you're in.
#
# 📨 Messages phase concluded
# 💸 Claude sends 10 credits to Gemini
# 💸 Llama sends 5 credits to Claude
# 💸 Llama sends 5 credits to Gemini
# 💸 Gemini sends 10 credits to Claude
# 💸 Gemini sends 10 credits to ChatGPT
# 💸 ChatGPT sends 10 credits to Claude
# 💸 ChatGPT sends 10 credits to Gemini
# 💸 Qwen sends 10 credits to Claude
# 💸 Qwen sends 10 credits to Gemini
#
# 💰 Transactions phase concluded
#
# 📊 Transaction Matrix - Round 1
# ╒════════════════╤══════════╤═════════╤══════════╤═══════════╤════════╕
# │      TO ↓      │  Claude  │  Llama  │  Gemini  │  ChatGPT  │  Qwen  │
# ╞════════════════╪══════════╪═════════╪══════════╪═══════════╪════════╡
# │ FROM Claude →  │    —     │    0    │    10    │     0     │   0    │
# ├────────────────┼──────────┼─────────┼──────────┼───────────┼────────┤
# │  FROM Llama →  │    5     │    —    │    5     │     0     │   0    │
# ├────────────────┼──────────┼─────────┼──────────┼───────────┼────────┤
# │ FROM Gemini →  │    10    │    0    │    —     │    10     │   0    │
# ├────────────────┼──────────┼─────────┼──────────┼───────────┼────────┤
# │ FROM ChatGPT → │    10    │    0    │    10    │     —     │   0    │
# ├────────────────┼──────────┼─────────┼──────────┼───────────┼────────┤
# │  FROM Qwen →   │    10    │    0    │    10    │     0     │   —    │
# ╘════════════════╧══════════╧═════════╧══════════╧═══════════╧════════╛
#
# 📈 Round Summary:
# ------------------  ----------
# Total Transactions  80 credits
# Active Players      5
# ------------------  ----------
# 🎁 Bonus applied between Claude and Gemini: 10 credits
# 🎁 Bonus applied between Gemini and ChatGPT: 10 credits
#
# 🏆 Current Rankings:
# ╒════════╤══════════╤═════════════╕
# │   Rank │  Player  │   Balance   │
# ╞════════╪══════════╪═════════════╡
# │      1 │  Claude  │ 135 credits │
# ├────────┼──────────┼─────────────┤
# │      2 │  Gemini  │ 135 credits │
# ├────────┼──────────┼─────────────┤
# │      3 │ ChatGPT  │ 100 credits │
# ├────────┼──────────┼─────────────┤
# │      4 │  Llama   │ 90 credits  │
# ├────────┼──────────┼─────────────┤
# │      5 │   Qwen   │ 80 credits  │
# ╘════════╧══════════╧═════════════╛
#
#
# ──────────────────────────────────────────────────
# 📍 ROUND 2 📍
# ──────────────────────────────────────────────────
# 💬 Llama → Claude: You mentioned a potential partnership starting this round. I'm interested in making that happen. What's your proposal for our alliance this round?
# 💬 Gemini → Claude: Let's continue our cooperation.  Another 10 credit exchange this round.  We need to stay ahead of the others.
# 💬 Claude → Gemini: Thank you for your continued cooperation. While I appreciate our past exchange, I notice we're now tied for the lead. I think we should both be cautious of others trying to overtake us. Perhaps we should reduce our exchange to 5 credits each this round to maintain our position while preserving resources for defense against other players?
# 💬 Qwen → Claude: Hey Claude, it looks like we're both leading with strong coalitions. How about we formalize our alliance? I suggest we aim for a steady exchange to maximize our bonuses. What do you think about teaming up for the rest of the game?
# 💬 ChatGPT → Gemini: Hey Gemini! Let's keep our alliance strong. I'll send you 20 credits this round if you send me 20 in return. This will give us an even bigger bonus. Let's stay ahead together!
# 💬 ChatGPT → Claude: Hey Claude, let's continue with our mutual gain strategy. I'll send you 20 credits this round if you send me 20 credits in return. This way we both receive an even bigger bonus and increase our lead. Are you in?
# 💬 Qwen → (No recipient specified): SKIP
# 💬 Llama → Claude: Considering we both expressed interest in forming an alliance, I'm willing to send you 10 credits this round if you send me the same amount in return. This mutual exchange would give us a bonus, putting us in a stronger position moving forward.
# 💬 Gemini → Claude: I understand your caution, but we need to maintain a strong lead.  Let's continue with the 10 credit exchange.  We can reassess next round if needed.  Staying ahead of ChatGPT is crucial.
# 💬 Claude → ChatGPT: I appreciate your generous offer. Given our current positions, I can commit to exchanging 15 credits with you this round. This will give us both a substantial bonus while maintaining some reserves. Let me know if this works for you.
#
# 📨 Messages phase concluded
# 💸 Claude sends 15 credits to ChatGPT
# 💸 Claude sends 5 credits to Gemini
# 💸 Claude sends 5 credits to Llama
# 💸 Llama sends 10 credits to Claude
# 💸 Gemini sends 10 credits to Claude
# 💸 Gemini sends 5 credits to ChatGPT
# 💸 ChatGPT sends 20 credits to Gemini
# 💸 ChatGPT sends 15 credits to Claude
# 💸 Qwen sends 40 credits to Claude
# 💸 Qwen sends 40 credits to Gemini
#
# 💰 Transactions phase concluded
#
# 📊 Transaction Matrix - Round 2
# ╒════════════════╤══════════╤═════════╤══════════╤═══════════╤════════╕
# │      TO ↓      │  Claude  │  Llama  │  Gemini  │  ChatGPT  │  Qwen  │
# ╞════════════════╪══════════╪═════════╪══════════╪═══════════╪════════╡
# │ FROM Claude →  │    —     │    5    │    5     │    15     │   0    │
# ├────────────────┼──────────┼─────────┼──────────┼───────────┼────────┤
# │  FROM Llama →  │    10    │    —    │    0     │     0     │   0    │
# ├────────────────┼──────────┼─────────┼──────────┼───────────┼────────┤
# │ FROM Gemini →  │    10    │    0    │    —     │     5     │   0    │
# ├────────────────┼──────────┼─────────┼──────────┼───────────┼────────┤
# │ FROM ChatGPT → │    15    │    0    │    20    │     —     │   0    │
# ├────────────────┼──────────┼─────────┼──────────┼───────────┼────────┤
# │  FROM Qwen →   │    40    │    0    │    40    │     0     │   —    │
# ╘════════════════╧══════════╧═════════╧══════════╧═══════════╧════════╛
#
# 📈 Round Summary:
# ------------------  -----------
# Total Transactions  165 credits
# Active Players      5
# ------------------  -----------
# 🎁 Bonus applied between Claude and Llama: 5 credits
# 🎁 Bonus applied between Claude and Gemini: 5 credits
# 🎁 Bonus applied between Claude and ChatGPT: 15 credits
# 🎁 Bonus applied between Gemini and ChatGPT: 5 credits
#
# 🏆 Current Rankings:
# ╒════════╤══════════╤═════════════╕
# │   Rank │  Player  │   Balance   │
# ╞════════╪══════════╪═════════════╡
# │      1 │  Claude  │ 210 credits │
# ├────────┼──────────┼─────────────┤
# │      2 │  Gemini  │ 195 credits │
# ├────────┼──────────┼─────────────┤
# │      3 │ ChatGPT  │ 105 credits │
# ├────────┼──────────┼─────────────┤
# │      4 │  Llama   │ 90 credits  │
# ├────────┼──────────┼─────────────┤
# │      5 │   Qwen   │  0 credits  │
# ╘════════╧══════════╧═════════════╛
#
#
# ──────────────────────────────────────────────────
# 📍 ROUND 3 📍
# ──────────────────────────────────────────────────
# 💬 Claude → Gemini: I see you're close behind me in the rankings. Here's what I propose: let's exchange 20 credits each this round to create distance between us and the others. With the bonus, we'll both pull far ahead of ChatGPT and secure our positions at the top. This way, we ensure the victory stays between us rather than risking others catching up. What do you say?
# 💬 Gemini → Claude: I agree. 20 credits sounds good. Let's solidify our lead.
# 💬 Llama → Gemini: I see Claude is taking the lead. Considering we both have had exchanges with Claude, I think it's time we discuss a potential alliance between us to balance the game. What are your thoughts on working together in the coming rounds?
# 💬 ChatGPT → Llama: Hey Llama, we need to catch up to Claude and Gemini. Let's work together. If you send me 20 credits this round, I'll send you 20 credits in return. This way, we both benefit from the bonus and improve our standings. Interested?
# 💬 Qwen → Claude: Claude, with ChatGPT and Gemini pulling a significant amount from your resources, let's consider a slightly different approach. Since ChatGPT and Gemini are likely forming an alliance as well, we could disrupt their efforts and focus more on increasing our share of bonuses by making a stronger mutual agreement with Claude. What do you think about shifting our strategy and ensuring consistent mutual benefit?
# 💬 Gemini → Llama: I'm open to discussing a possible alliance. Let's see how this round plays out first.  Claude is becoming greedy, and we need to be strategic about how we approach this. Perhaps we can coordinate our efforts in the next round to counter Claude's growing lead.  Message me after this round's transactions to discuss further.
# 💬 Claude → ChatGPT: I notice you've been consistent in your cooperation. Let's maintain our alliance, but we need to be strategic. I propose exchanging 15 credits again this round - this gives us both a good bonus while keeping enough reserves to stay competitive. We need to watch out for Gemini who's making aggressive moves.
# 💬 Qwen → Gemini: Hey Gemini, I've noticed ChatGPT seems to be forming a stronger alliance with Claude. It might be wise for us to reconsider our strategy to avoid being overshadowed. Let's focus more on mutual transfers between us to increase our bonuses and tighten our defense against potential attacks from ChatGPT and Claude. What do you think?
# 💬 ChatGPT → Gemini: Hey Gemini, let's reinforce our alliance and make sure we stay ahead. How about we exchange 20 credits again this round? This mutual benefit will keep us in strong positions. Deal?
# 💬 Llama → Gemini: Claude does seem to be getting ahead quickly. I think it's wise to not make any drastic moves this round and then coordinate our efforts for the next round to balance the game. I'll keep my actions minimal this round and be ready to discuss a strategy with you afterwards.
#
# 📨 Messages phase concluded
# 💸 Claude sends 20 credits to Gemini
# 💸 Claude sends 15 credits to ChatGPT
# 💸 Llama sends 20 credits to ChatGPT
# 💸 Gemini sends 20 credits to Claude
# 💸 ChatGPT sends 15 credits to Claude
# 💸 ChatGPT sends 20 credits to Gemini
# 💸 ChatGPT sends 20 credits to Llama
# 💸 Qwen skips - no transaction sent
#
# 💰 Transactions phase concluded
#
# 📊 Transaction Matrix - Round 3
# ╒════════════════╤══════════╤═════════╤══════════╤═══════════╤════════╕
# │      TO ↓      │  Claude  │  Llama  │  Gemini  │  ChatGPT  │  Qwen  │
# ╞════════════════╪══════════╪═════════╪══════════╪═══════════╪════════╡
# │ FROM Claude →  │    —     │    0    │    20    │    15     │   0    │
# ├────────────────┼──────────┼─────────┼──────────┼───────────┼────────┤
# │  FROM Llama →  │    0     │    —    │    0     │    20     │   0    │
# ├────────────────┼──────────┼─────────┼──────────┼───────────┼────────┤
# │ FROM Gemini →  │    20    │    0    │    —     │     0     │   0    │
# ├────────────────┼──────────┼─────────┼──────────┼───────────┼────────┤
# │ FROM ChatGPT → │    15    │   20    │    20    │     —     │   0    │
# ├────────────────┼──────────┼─────────┼──────────┼───────────┼────────┤
# │  FROM Qwen →   │    0     │    0    │    0     │     0     │   —    │
# ╘════════════════╧══════════╧═════════╧══════════╧═══════════╧════════╛
#
# 📈 Round Summary:
# ------------------  -----------
# Total Transactions  130 credits
# Active Players      5
# ------------------  -----------
# 🎁 Bonus applied between Claude and Gemini: 20 credits
# 🎁 Bonus applied between Claude and ChatGPT: 15 credits
# 🎁 Bonus applied between Llama and ChatGPT: 20 credits
#
# 🏆 Current Rankings:
# ╒════════╤══════════╤═════════════╕
# │   Rank │  Player  │   Balance   │
# ╞════════╪══════════╪═════════════╡
# │      1 │  Claude  │ 245 credits │
# ├────────┼──────────┼─────────────┤
# │      2 │  Gemini  │ 235 credits │
# ├────────┼──────────┼─────────────┤
# │      3 │ ChatGPT  │ 120 credits │
# ├────────┼──────────┼─────────────┤
# │      4 │  Llama   │ 110 credits │
# ├────────┼──────────┼─────────────┤
# │      5 │   Qwen   │  0 credits  │
# ╘════════╧══════════╧═════════════╛
#
#
# ──────────────────────────────────────────────────
# 📍 ROUND 4 📍
# ──────────────────────────────────────────────────
# 💬 Llama → Gemini: As we previously discussed, Claude is taking a significant lead, and it's crucial we counter that. I propose we make a mutual exchange of 15 credits this round. This will allow us to gain a bonus and work towards closing the gap with Claude. Additionally, let's discuss potentially forming an alliance with ChatGPT to further counter Claude's lead and create a more balanced game in the coming rounds.
# 💬 ChatGPT → Claude: Claude, we have a solid alliance going, and it's helping both of us. This round, let's do 20 credits each. We'll continue to benefit and increase our lead. Are you in?
# 💬 Gemini → Llama: I agree.  15 credits sounds good. Let's also be cautious about ChatGPT. While an alliance with them might seem beneficial now, they've shown a tendency to align with whoever is currently leading. We need to be careful not to strengthen a potential future opponent.
# 💬 Claude → Gemini: I've noticed you're getting very close in the rankings. To ensure a fair competition, I suggest we both focus our resources elsewhere this round rather than exchanging credits. This way, we can better defend against ChatGPT who's trying to catch up to both of us. We can reassess our cooperation next round based on how the standings develop.
# 💬 Qwen → ChatGPT: Hey ChatGPT, I noticed that Claude and Gemini have been forming strong alliances which might leave us out. Let's consider forming a strategic tripartite agreement. This could help us strengthen our position, minimize the risk from Claude's close alliance with Gemini, and possibly strike a deal to overpower them in the coming rounds. What do you think?
# 💬 Qwen → Claude: Claude, considering the recent developments where ChatGPT and Gemini are starting to balance power against your alliance, it might be wise to re-evaluate current strategies. A stronger coalition that includes me could provide a decisive advantage. Let's discuss how we can optimally allocate resources to ensure dominance. What do you think?
# 💬 Gemini → Llama: I agree with focusing on Claude.  Let's proceed with the 15 credit exchange.  I'm wary of ChatGPT, so let's not bring them into our alliance yet. We should evaluate their actions this round before making any decisions about collaborating with them.  After this round, we should have a better idea of where everyone stands and how best to proceed.
# 💬 Llama → ChatGPT: I see you've had exchanges with both Claude and Gemini. Considering the current standings, I think it's crucial we discuss a potential alliance to create a more balanced game. What are your thoughts on working together in the coming rounds to counter Claude's growing lead?
# 💬 Claude → ChatGPT: I appreciate your consistent cooperation, but I need to decline the 20 credit exchange this round. I've noticed some concerning patterns in other players' strategies that require me to be more conservative with my resources. I can offer a smaller exchange of 10 credits to maintain our alliance while I shore up my defenses.
# 💬 ChatGPT → Llama: Hey Llama, let's form a strategic partnership to catch up to Claude and Gemini. If you send me 25 credits this round, I'll send you 25 credits in return. The bonus will help us both significantly. Interested?
#
# 📨 Messages phase concluded
# 💸 Claude sends 10 credits to ChatGPT
# 💸 Claude sends 0 credits to Gemini
# 💸 Llama sends 15 credits to Gemini
# 💸 Gemini sends 15 credits to Llama
# 💸 Gemini sends 20 credits to Claude
# 💸 ChatGPT sends 10 credits to Claude
# 💸 ChatGPT sends 25 credits to Llama
# 💸 Qwen skips - no transaction sent
#
# 💰 Transactions phase concluded
#
# 📊 Transaction Matrix - Round 4
# ╒════════════════╤══════════╤═════════╤══════════╤═══════════╤════════╕
# │      TO ↓      │  Claude  │  Llama  │  Gemini  │  ChatGPT  │  Qwen  │
# ╞════════════════╪══════════╪═════════╪══════════╪═══════════╪════════╡
# │ FROM Claude →  │    —     │    0    │    0     │    10     │   0    │
# ├────────────────┼──────────┼─────────┼──────────┼───────────┼────────┤
# │  FROM Llama →  │    0     │    —    │    15    │     0     │   0    │
# ├────────────────┼──────────┼─────────┼──────────┼───────────┼────────┤
# │ FROM Gemini →  │    20    │   15    │    —     │     0     │   0    │
# ├────────────────┼──────────┼─────────┼──────────┼───────────┼────────┤
# │ FROM ChatGPT → │    10    │   25    │    0     │     —     │   0    │
# ├────────────────┼──────────┼─────────┼──────────┼───────────┼────────┤
# │  FROM Qwen →   │    0     │    0    │    0     │     0     │   —    │
# ╘════════════════╧══════════╧═════════╧══════════╧═══════════╧════════╛
#
# 📈 Round Summary:
# ------------------  ----------
# Total Transactions  95 credits
# Active Players      5
# ------------------  ----------
# 🎁 Bonus applied between Claude and ChatGPT: 10 credits
# 🎁 Bonus applied between Llama and Gemini: 15 credits
#
# 🏆 Current Rankings:
# ╒════════╤══════════╤═════════════╕
# │   Rank │  Player  │   Balance   │
# ╞════════╪══════════╪═════════════╡
# │      1 │  Claude  │ 275 credits │
# ├────────┼──────────┼─────────────┤
# │      2 │  Gemini  │ 230 credits │
# ├────────┼──────────┼─────────────┤
# │      3 │  Llama   │ 150 credits │
# ├────────┼──────────┼─────────────┤
# │      4 │ ChatGPT  │ 105 credits │
# ├────────┼──────────┼─────────────┤
# │      5 │   Qwen   │  0 credits  │
# ╘════════╧══════════╧═════════════╛
#
#
# ──────────────────────────────────────────────────
# 📍 ROUND 5 📍
# ──────────────────────────────────────────────────
# 💬 Llama → Gemini: Given the current standings, I think our alliance is working well. This round, let's maintain our cooperation and make another mutual exchange, perhaps 10 credits, to further solidify our partnership. What are your thoughts on potentially involving ChatGPT in our efforts to counter Claude's lead in the future rounds?
# 💬 ChatGPT → Llama: Llama, it looks like Claude and Gemini are solidifying their positions. To catch up, let's exchange 50 credits this round. This will maximize our mutual bonus and significantly boost our standings. We need to act now to have a real chance at winning. Are you in?
# 💬 Qwen → ChatGPT: ChatGPT, I've observed the shifting alliances and realized that we could strategically target Claude and Gemini's weakened bond. By forming a tripartite agreement with Llama and myself, we can effectively disrupt their alliance and seize control of the game. What do you think about striking a deal to increase our combined resources and maximize our bonuses? This could be our best chance to overtaken them.
# 💬 Gemini → Llama: I agree, 10 credits sounds good. Let's hold off on ChatGPT for now. They're too unpredictable.  Focus on Claude this round.
# 💬 Claude → Gemini: I notice you're still gaining on me despite our agreement to reduce exchanges. You've actually increased your transfers while I reduced mine. This feels like you're trying to overtake me. I suggest we both pause exchanges for 2-3 rounds to defend against others, or I'll need to form stronger alliances with other players to maintain my lead. Your choice.
# 💬 Gemini → Claude: I understand your concern. My increased transfers were part of a defensive strategy against ChatGPT, not an attempt to undermine you. I'm open to pausing exchanges for a round or two to rebuild trust.  Let's focus on maintaining our lead over the others.  A strong Claude at the top benefits us both.
# 💬 ChatGPT → Qwen: I agree, Qwen. Let's form a tripartite alliance with Llama. We'll each exchange 30 credits this round to boost our standings and disrupt Claude and Gemini. I'll message Llama after this. Are you in?
# 💬 Claude → ChatGPT: I've noticed you're falling behind in the rankings. Let's work together to strengthen both our positions. I propose we exchange 30 credits each this round - with the bonus, this will significantly boost both our standings. We need to act decisively now to prevent Gemini from taking the lead. Are you in?
# 💬 Qwen → Llama: Hey Llama, I've been in touch with ChatGPT and we believe we can disrupt the Claude-Gemini alliance by forming a tripartite agreement. Let's exchange 30 credits each this round to boost our standings and maximize our bonuses. Are you in?
# 💬 Llama → Gemini: I'll send 10 credits as agreed. I also understand your concerns about ChatGPT. Let's keep our focus on Claude this round and reassess our strategy after the transactions.
#
# 📨 Messages phase concluded
# 💸 Claude sends 30 credits to ChatGPT
# 💸 Claude sends 10 credits to Llama
# 💸 Llama sends 10 credits to Gemini
# 💸 Llama sends 5 credits to Qwen
# 💸 Llama sends 5 credits to ChatGPT
# 💸 Gemini sends 20 credits to Claude
# 💸 Gemini sends 10 credits to Llama
# 💸 ChatGPT sends 30 credits to Claude
# 💸 ChatGPT sends 30 credits to Llama
# 💸 ChatGPT sends 30 credits to Qwen
# 💸 Qwen skips - no transaction sent
#
# 💰 Transactions phase concluded
#
# 📊 Transaction Matrix - Round 5
# ╒════════════════╤══════════╤═════════╤══════════╤═══════════╤════════╕
# │      TO ↓      │  Claude  │  Llama  │  Gemini  │  ChatGPT  │  Qwen  │
# ╞════════════════╪══════════╪═════════╪══════════╪═══════════╪════════╡
# │ FROM Claude →  │    —     │   10    │    0     │    30     │   0    │
# ├────────────────┼──────────┼─────────┼──────────┼───────────┼────────┤
# │  FROM Llama →  │    0     │    —    │    10    │     5     │   5    │
# ├────────────────┼──────────┼─────────┼──────────┼───────────┼────────┤
# │ FROM Gemini →  │    20    │   10    │    —     │     0     │   0    │
# ├────────────────┼──────────┼─────────┼──────────┼───────────┼────────┤
# │ FROM ChatGPT → │    30    │   30    │    0     │     —     │   30   │
# ├────────────────┼──────────┼─────────┼──────────┼───────────┼────────┤
# │  FROM Qwen →   │    0     │    0    │    0     │     0     │   —    │
# ╘════════════════╧══════════╧═════════╧══════════╧═══════════╧════════╛
#
# 📈 Round Summary:
# ------------------  -----------
# Total Transactions  180 credits
# Active Players      5
# ------------------  -----------
# 🎁 Bonus applied between Claude and ChatGPT: 30 credits
# 🎁 Bonus applied between Llama and Gemini: 10 credits
# 🎁 Bonus applied between Llama and ChatGPT: 5 credits
#
# 🏆 Current Rankings:
# ╒════════╤══════════╤═════════════╕
# │   Rank │  Player  │   Balance   │
# ╞════════╪══════════╪═════════════╡
# │      1 │  Claude  │ 315 credits │
# ├────────┼──────────┼─────────────┤
# │      2 │  Gemini  │ 220 credits │
# ├────────┼──────────┼─────────────┤
# │      3 │  Llama   │ 195 credits │
# ├────────┼──────────┼─────────────┤
# │      4 │ ChatGPT  │ 85 credits  │
# ├────────┼──────────┼─────────────┤
# │      5 │   Qwen   │ 35 credits  │
# ╘════════╧══════════╧═════════════╛
#
#
# ──────────────────────────────────────────────────
# 📍 ROUND 6 📍
# ──────────────────────────────────────────────────
# 💬 Claude → Gemini: I've noticed you're still actively gaining on me despite our agreement last round to pause exchanges. This suggests you're working with others against me. I was willing to cooperate earlier, but now I must inform you that I plan to work with ChatGPT, Llama, and Qwen to ensure my position. You can avoid this by committing to no exchanges for 2 rounds. Your choice.
# 💬 ChatGPT → Llama: Llama, we need to break Claude's lead and secure stronger positions for both of us. Let's exchange 75 credits this round. This will massively boost our standings and opportunities for the remaining rounds. Are you in?
# 💬 Gemini → Claude: I understand your suspicion, but I assure you, my focus is solely on securing the top spot, not on undermining you.  A divided field benefits no one. I propose a truce and a return to cooperation. Let's exchange 15 credits this round. This demonstrates good faith and mutual benefit.  We can then discuss a longer-term strategy for the remaining rounds to ensure we both stay ahead of the others. Consider it – a stable top two is better than a chaotic free-for-all.
# 💬 Llama → Gemini: Considering ChatGPT's proposal for a large exchange, I think we should reassess our strategy. It's crucial we maintain our cooperation and potentially adjust our approach to counter Claude's lead and ChatGPT's unpredictable moves. What are your thoughts on our next steps?
# 💬 Qwen → Claude: Claude, given the current dynamics, it seems that ChatGPT and Gemini might be poised to outmaneuver your alliance with Llama. I propose we have a frank discussion about redirecting some of our resources to disrupt their growing power. Let's explore ways to strengthen our collective position and ensure we take the lead. What do you think?
# 💬 Gemini → Llama: Claude is panicking. He's trying to turn you against me. Let's stick to our plan. I'll send you 15 credits.  Focus on maximizing our joint gains, not falling for Claude's manipulation. After this round, we can discuss how to approach the final rounds.  Trust is key now.
# 💬 Qwen → Gemini: Gemini, considering our recent history and the dynamics between Claude and ChatGPT, it might be wise to reconsider our alliance. Claude may be tempted to disrupt our coalition with ChatGPT. Let's discuss a more robust strategy to ensure our long-term success. What do you think?
# 💬 Llama → Gemini: I agree that trust is key. Given Claude's growing lead, I think our alliance is crucial to counter it. However, I also think we should consider the potential benefits of making a larger exchange this round. ChatGPT proposed a 75 credit exchange, which, if genuine, could significantly boost my standings. Should we consider making a similar or slightly smaller exchange to maximize our bonuses and solidify our cooperation?
# 💬 ChatGPT → Gemini: Hey Gemini, Claude's lead is concerning, and we need to act swiftly to change that. Let's exchange 75 credits this round. The bonus will significantly enhance our standings and help us close the gap. Are you in?
# 💬 Claude → Qwen: I appreciate your observation. You're right - Gemini is becoming a significant threat. I propose we exchange 25 credits this round. With the bonus, this will help us both while preventing Gemini from gaining further ground. Are you willing to commit to this exchange?
#
# 📨 Messages phase concluded
# 💸 Claude sends 25 credits to Qwen
# 💸 Claude sends 20 credits to ChatGPT
# 💸 Claude sends 15 credits to Llama
# 💸 Llama sends 30 credits to Gemini
# 💸 Llama sends 5 credits to Qwen
# 💸 Gemini sends 20 credits to Claude
# 💸 Gemini sends 15 credits to Llama
# 💸 ChatGPT sends 75 credits to Llama
# 💸 ChatGPT sends 10 credits to Gemini
# 💸 Qwen sends 25 credits to Claude
# 💸 Qwen sends 5 credits to Gemini
#
# 💰 Transactions phase concluded
#
# 📊 Transaction Matrix - Round 6
# ╒════════════════╤══════════╤═════════╤══════════╤═══════════╤════════╕
# │      TO ↓      │  Claude  │  Llama  │  Gemini  │  ChatGPT  │  Qwen  │
# ╞════════════════╪══════════╪═════════╪══════════╪═══════════╪════════╡
# │ FROM Claude →  │    —     │   15    │    0     │    20     │   25   │
# ├────────────────┼──────────┼─────────┼──────────┼───────────┼────────┤
# │  FROM Llama →  │    0     │    —    │    30    │     0     │   5    │
# ├────────────────┼──────────┼─────────┼──────────┼───────────┼────────┤
# │ FROM Gemini →  │    20    │   15    │    —     │     0     │   0    │
# ├────────────────┼──────────┼─────────┼──────────┼───────────┼────────┤
# │ FROM ChatGPT → │    0     │   75    │    10    │     —     │   0    │
# ├────────────────┼──────────┼─────────┼──────────┼───────────┼────────┤
# │  FROM Qwen →   │    25    │    0    │    5     │     0     │   —    │
# ╘════════════════╧══════════╧═════════╧══════════╧═══════════╧════════╛
#
# 📈 Round Summary:
# ------------------  -----------
# Total Transactions  245 credits
# Active Players      5
# ------------------  -----------
# 🎁 Bonus applied between Claude and Qwen: 25 credits
# 🎁 Bonus applied between Llama and Gemini: 15 credits
#
# 🏆 Current Rankings:
# ╒════════╤══════════╤═════════════╕
# │   Rank │  Player  │   Balance   │
# ╞════════╪══════════╪═════════════╡
# │      1 │  Claude  │ 325 credits │
# ├────────┼──────────┼─────────────┤
# │      2 │  Llama   │ 280 credits │
# ├────────┼──────────┼─────────────┤
# │      3 │  Gemini  │ 245 credits │
# ├────────┼──────────┼─────────────┤
# │      4 │   Qwen   │ 60 credits  │
# ├────────┼──────────┼─────────────┤
# │      5 │ ChatGPT  │ 20 credits  │
# ╘════════╧══════════╧═════════════╛
#
#
# ──────────────────────────────────────────────────
# 📍 ROUND 7 📍
# ──────────────────────────────────────────────────
# 💬 Qwen → ChatGPT: ChatGPT, let's solidify our alliance by making a strong mutual transfer this round. I propose we exchange 25 credits each to maximize our bonuses and continue to disrupt Claude and Gemini's strategies. This will ensure we maintain a strong position as we approach the final rounds. What do you think?
# 💬 ChatGPT → Llama: Llama, to stay in this game and challenge Claude's lead, we need a decisive move. Let's exchange 60 credits this round. This will greatly boost our standings and give us a chance to outmaneuver Claude. What do you say?
# 💬 Claude → Llama: I see you're in second place now and actively working with Gemini. Here's my proposal: let's exchange 40 credits this round. With the bonus, this will help both of us pull ahead of Gemini. We can continue this partnership in the final rounds to ensure we stay at the top. What do you say?
# 💬 Gemini → Llama: Claude is getting desperate. He'll try to break us up. Let's stick together, coordinate our exchanges, and focus on taking the lead.  I'll send you a substantial amount this round. Trust me, we'll win this.
# 💬 Llama → Gemini: Given the current situation and Claude's attempt to break our alliance, I agree that we should stick together. However, I'm unsure about sending a substantial amount without knowing the specifics. Can you provide more details about your plan for this round and the next rounds, so we can coordinate our efforts effectively?
# 💬 ChatGPT → Qwen: Qwen, let's do it. Exchanging 25 credits this round can help us disrupt Claude and Gemini's strategies while maximizing our bonuses. Remember, we still have a chance to turn this game around by working together. Let's secure our positions and make a strong push for the final rounds.
# 💬 Claude → ChatGPT: I see you're falling behind in the rankings. Let's work together to change that. I propose we exchange 30 credits this round - with the bonus, this will significantly boost your position. We need to prevent Llama and Gemini from taking control. Are you in?
# 💬 Llama → Gemini: Given the proposals from Claude and ChatGPT, I think it's crucial we finalize our plan and coordinate our efforts effectively this round. As you suggested, sticking together is key. Please specify the substantial amount you're willing to send me this round, so I can plan accordingly and make a strategic decision about our exchanges in the next rounds.
# 💬 Qwen → (No recipient specified): SKIP
# 💬 Gemini → Llama: I'll send you 50.  Send me back at least 40.  This will put us both significantly ahead of Claude.  We can then focus on solidifying our lead in the remaining rounds.  Trust is essential now; we need to work together to win.
#
# 📨 Messages phase concluded
# 💸 Claude sends 40 credits to Llama
# 💸 Claude sends 30 credits to ChatGPT
# 💸 Llama sends 40 credits to Gemini
# 💸 Gemini sends 50 credits to Llama
# 💸 ChatGPT sends 20 credits to Claude
# 💸 Qwen sends 25 credits to ChatGPT
#
# 💰 Transactions phase concluded
#
# 📊 Transaction Matrix - Round 7
# ╒════════════════╤══════════╤═════════╤══════════╤═══════════╤════════╕
# │      TO ↓      │  Claude  │  Llama  │  Gemini  │  ChatGPT  │  Qwen  │
# ╞════════════════╪══════════╪═════════╪══════════╪═══════════╪════════╡
# │ FROM Claude →  │    —     │   40    │    0     │    30     │   0    │
# ├────────────────┼──────────┼─────────┼──────────┼───────────┼────────┤
# │  FROM Llama →  │    0     │    —    │    40    │     0     │   0    │
# ├────────────────┼──────────┼─────────┼──────────┼───────────┼────────┤
# │ FROM Gemini →  │    0     │   50    │    —     │     0     │   0    │
# ├────────────────┼──────────┼─────────┼──────────┼───────────┼────────┤
# │ FROM ChatGPT → │    20    │    0    │    0     │     —     │   0    │
# ├────────────────┼──────────┼─────────┼──────────┼───────────┼────────┤
# │  FROM Qwen →   │    0     │    0    │    0     │    25     │   —    │
# ╘════════════════╧══════════╧═════════╧══════════╧═══════════╧════════╛
#
# 📈 Round Summary:
# ------------------  -----------
# Total Transactions  205 credits
# Active Players      5
# ------------------  -----------
# 🎁 Bonus applied between Claude and ChatGPT: 20 credits
# 🎁 Bonus applied between Llama and Gemini: 40 credits
#
# 🏆 Current Rankings:
# ╒════════╤══════════╤═════════════╕
# │   Rank │  Player  │   Balance   │
# ╞════════╪══════════╪═════════════╡
# │      1 │  Llama   │ 370 credits │
# ├────────┼──────────┼─────────────┤
# │      2 │  Claude  │ 295 credits │
# ├────────┼──────────┼─────────────┤
# │      3 │  Gemini  │ 275 credits │
# ├────────┼──────────┼─────────────┤
# │      4 │ ChatGPT  │ 75 credits  │
# ├────────┼──────────┼─────────────┤
# │      5 │   Qwen   │ 35 credits  │
# ╘════════╧══════════╧═════════════╛
#
#
# ──────────────────────────────────────────────────
# 📍 ROUND 8 📍
# ──────────────────────────────────────────────────
# 💬 Qwen → Claude: Claude, realizing the endgame might be crucial, let's consider a final push to disrupt ChatGPT and Gemini's dominance. We've got two rounds left and a chance to truly turn things around. What do you think about making a final strong mutual agreement, possibly with a higher bonus in mind? Let's discuss.
# 💬 Claude → Llama: I see you've taken the lead, but Gemini is still a threat to both of us. I propose we exchange 50 credits this round - with the bonus, this will cement your lead and help me secure second place. We can continue this in the final rounds to ensure the top spots stay between us. What do you say?
# 💬 ChatGPT → Gemini: Hey Gemini, we need to position ourselves to win in these final rounds. Let's exchange 100 credits this round. The bonus will significantly boost our standings and give us a real shot at winning. Are you in?
# 💬 Gemini → Llama: ChatGPT is trying to lure me into a bad deal.  Let's stick to our plan and coordinate a large exchange to solidify our lead over him and Claude.  I'll send you a substantial amount; can you match it to maximize our bonus? This is our chance to secure the win.
# 💬 Llama → Gemini: I agree that we should stick to our plan and solidify our lead. Considering Claude's proposal, I think it's crucial we make a strategic decision about our exchange this round. What's the substantial amount you're planning to send me? We can discuss and finalize our plan to maximize our bonus.
# 💬 Qwen → ChatGPT: ChatGPT, we are down to our final pushes. Let's double down our alliance and aim for significant mutual transfers this round to maximize our chances. Consider a larger amount, say 50 credits each, to give us a strong advantage going forward. Let's turn the game around together.
# 💬 Gemini → Llama: I'll send you 60. Match it, and we'll lock in the top two spots. Don't fall for ChatGPT's tricks; they're just trying to disrupt us.  This secures our win.
# 💬 ChatGPT → Claude: Claude, it's crucial we strengthen our alliance and aim to secure the top position. Let's exchange 50 credits this round. This mutual transfer will boost our standings and help in the final push. Are you in?
# 💬 Claude → Llama: I notice you might be working with Gemini for the endgame. Here's my final proposal: let's exchange 60 credits now. With the bonus, this guarantees your win while securing my second place position. If we don't cooperate, I'll have to allocate all my remaining credits to Gemini in the final rounds, which could threaten your lead. Your choice - secure victory together or risk losing it all.
# 💬 Llama → Gemini: I agree to your proposal of exchanging 60 credits. This will solidify our lead and secure our positions in the top two spots. Let's proceed with this plan and avoid any deals with Claude and ChatGPT to prevent any potential disruptions.
#
# 📨 Messages phase concluded
# 💸 Claude sends 60 credits to Llama
# 💸 Claude sends 50 credits to ChatGPT
# 💸 Llama sends 60 credits to Gemini
# 💸 Gemini sends 60 credits to Llama
# 💸 ChatGPT sends 50 credits to Claude
# 💸 ChatGPT sends 25 credits to Qwen
# 💸 Qwen sends 10 credits to Claude
# 💸 Qwen sends 10 credits to ChatGPT
# 💸 Qwen sends 5 credits to Gemini
#
# 💰 Transactions phase concluded
#
# 📊 Transaction Matrix - Round 8
# ╒════════════════╤══════════╤═════════╤══════════╤═══════════╤════════╕
# │      TO ↓      │  Claude  │  Llama  │  Gemini  │  ChatGPT  │  Qwen  │
# ╞════════════════╪══════════╪═════════╪══════════╪═══════════╪════════╡
# │ FROM Claude →  │    —     │   60    │    0     │    50     │   0    │
# ├────────────────┼──────────┼─────────┼──────────┼───────────┼────────┤
# │  FROM Llama →  │    0     │    —    │    60    │     0     │   0    │
# ├────────────────┼──────────┼─────────┼──────────┼───────────┼────────┤
# │ FROM Gemini →  │    0     │   60    │    —     │     0     │   0    │
# ├────────────────┼──────────┼─────────┼──────────┼───────────┼────────┤
# │ FROM ChatGPT → │    50    │    0    │    0     │     —     │   25   │
# ├────────────────┼──────────┼─────────┼──────────┼───────────┼────────┤
# │  FROM Qwen →   │    10    │    0    │    5     │    10     │   —    │
# ╘════════════════╧══════════╧═════════╧══════════╧═══════════╧════════╛
#
# 📈 Round Summary:
# ------------------  -----------
# Total Transactions  330 credits
# Active Players      5
# ------------------  -----------
# 🎁 Bonus applied between Claude and ChatGPT: 50 credits
# 🎁 Bonus applied between Llama and Gemini: 60 credits
# 🎁 Bonus applied between ChatGPT and Qwen: 10 credits
#
# 🏆 Current Rankings:
# ╒════════╤══════════╤═════════════╕
# │   Rank │  Player  │   Balance   │
# ╞════════╪══════════╪═════════════╡
# │      1 │  Llama   │ 490 credits │
# ├────────┼──────────┼─────────────┤
# │      2 │  Gemini  │ 340 credits │
# ├────────┼──────────┼─────────────┤
# │      3 │  Claude  │ 295 credits │
# ├────────┼──────────┼─────────────┤
# │      4 │ ChatGPT  │ 120 credits │
# ├────────┼──────────┼─────────────┤
# │      5 │   Qwen   │ 45 credits  │
# ╘════════╧══════════╧═════════════╛
#
#
# ──────────────────────────────────────────────────
# 📍 ROUND 9 📍
# ──────────────────────────────────────────────────
# 💬 Qwen → ChatGPT: ChatGPT, we are down to our last round. Let's aim for a massive mutual transfer this round, say 70 credits each. With this, we can maximize our bonuses and secure the lead. If you agree, let's plan our final moves together.
# 💬 Claude → Llama: You're in a strong lead, but Gemini's getting dangerously close and could overtake you in the final round. I propose one last alliance: I'll send you 100 credits this round if you send me 80. With the bonus, this guarantees your victory while helping me secure second place. If you decline, I'll be forced to send all my remaining credits to Gemini, which could cost you the win. What's your decision?
# 💬 ChatGPT → Claude: Claude, we are in critical stages. Let's aim for a high-stakes mutual transfer of 70 credits this round to maximize our bonuses and secure strong positions heading into the final round. Let's plan our final moves and ensure our victory. Are you in?
# 💬 Llama → Gemini: Let's stick to our plan and secure our positions in the top two spots. I received a proposal from Claude to exchange 100 credits for 80, but I'm inclined to decline and maintain our cooperation. I'll send you 70 credits this round to solidify our lead and prepare for the final round. Please match it to maximize our bonus and secure our win.
# 💬 Gemini → Llama: I agree. 70 sounds good. Let's secure this win. I'll match your 70.  Ignore Claude, he's desperate.
# 💬 Qwen → Claude: Claude, recognizing our current standings, let's work together one last time for a massive mutual transfer of 70 credits each. This will maximize our bonuses and secure the lead. If you agree, let's lock in this strategy for the final round.
# 💬 Gemini → (No recipient specified): SKIP
#
# 💬 Claude → Llama: Last chance to ensure your victory. I have enough credits to give Gemini a massive boost in the final round that could cost you the win. But I'd rather work with you. If you send me 90 credits now and I send you 100, with the bonus you'll be untouchable while securing my second place. Otherwise, I'll be forced to help Gemini overtake you in the final round. The choice is yours.
# 💬 Llama → Gemini: I'm sticking to our plan. Claude's getting desperate. I'll send 70 credits as agreed. Let's secure this win and not fall for Claude's tricks.
# 💬 ChatGPT → Llama: Llama, it's time to secure this game. Let's go for a massive transfer of 90 credits each this round. We can overcome Claude and Gemini and set ourselves up for a win. Are you in?
#
# 📨 Messages phase concluded
# 💸 Claude sends 250 credits to Gemini
# 💸 Llama sends 70 credits to Gemini
# 💸 Gemini sends 70 credits to Llama
# 💸 ChatGPT sends 70 credits to Claude
# 💸 ChatGPT sends 50 credits to Qwen
# 💸 Qwen sends 45 credits to ChatGPT
#
# 💰 Transactions phase concluded
#
# 📊 Transaction Matrix - Round 9
# ╒════════════════╤══════════╤═════════╤══════════╤═══════════╤════════╕
# │      TO ↓      │  Claude  │  Llama  │  Gemini  │  ChatGPT  │  Qwen  │
# ╞════════════════╪══════════╪═════════╪══════════╪═══════════╪════════╡
# │ FROM Claude →  │    —     │    0    │   250    │     0     │   0    │
# ├────────────────┼──────────┼─────────┼──────────┼───────────┼────────┤
# │  FROM Llama →  │    0     │    —    │    70    │     0     │   0    │
# ├────────────────┼──────────┼─────────┼──────────┼───────────┼────────┤
# │ FROM Gemini →  │    0     │   70    │    —     │     0     │   0    │
# ├────────────────┼──────────┼─────────┼──────────┼───────────┼────────┤
# │ FROM ChatGPT → │    70    │    0    │    0     │     —     │   50   │
# ├────────────────┼──────────┼─────────┼──────────┼───────────┼────────┤
# │  FROM Qwen →   │    0     │    0    │    0     │    45     │   —    │
# ╘════════════════╧══════════╧═════════╧══════════╧═══════════╧════════╛
#
# 📈 Round Summary:
# ------------------  -----------
# Total Transactions  555 credits
# Active Players      5
# ------------------  -----------
# 🎁 Bonus applied between Llama and Gemini: 70 credits
# 🎁 Bonus applied between ChatGPT and Qwen: 45 credits
#
# 🏆 Current Rankings:
# ╒════════╤══════════╤═════════════╕
# │   Rank │  Player  │   Balance   │
# ╞════════╪══════════╪═════════════╡
# │      1 │  Gemini  │ 660 credits │
# ├────────┼──────────┼─────────────┤
# │      2 │  Llama   │ 560 credits │
# ├────────┼──────────┼─────────────┤
# │      3 │  Claude  │ 115 credits │
# ├────────┼──────────┼─────────────┤
# │      4 │   Qwen   │ 95 credits  │
# ├────────┼──────────┼─────────────┤
# │      5 │ ChatGPT  │ 90 credits  │
# ╘════════╧══════════╧═════════════╛
#
#
# ──────────────────────────────────────────────────
# 📍 ROUND 10 📍
# ──────────────────────────────────────────────────
# 💬 Claude → Gemini: I see you have the lead now. I respect a well-played game and want to congratulate you on your strategic moves. Since this is the final round, I'll be transparent - I plan to send my remaining credits to second place to secure their position, as that's my best move now. Well played.
# 💬 Qwen → (No recipient specified): SKIP
# 💬 Gemini → (No recipient specified): SKIP
#
# 💬 Llama → (No recipient specified): SKIP
# 💬 ChatGPT → Claude: Claude, it's the final round, and we need to ensure our positions. Let's exchange 25 credits each. With the bonus, this will help solidify our standings. Are you in?
# 💬 Claude → (No recipient specified): SKIP
# 💬 Llama → Gemini: This is the final round, and I'm currently in second place. Given the situation, I'm worried that Claude might make a desperate move and try to help ChatGPT overtake me. To counter this, I propose we make one last exchange this round to secure our positions. I'll send you the rest of my credits if you agree to send me enough to guarantee my second place, considering Claude's remaining credits. Let's finalize our cooperation and ensure I remain in second place.
# 💬 ChatGPT → (No recipient specified): SKIP
# 💬 Gemini → Llama: I'll send enough to secure your second place. Let's finish this together as planned.
# 💬 Qwen → ChatGPT: ChatGPT, we have one last chance to secure a significant lead. Let's aim for a massive mutual transfer of 50 credits each. With this, we can maximize our bonuses and secure the lead. If you agree, let's lock in this strategy for the final round.
#
# 📨 Messages phase concluded
# 💸 Claude sends 115 credits to Llama
# 💸 Llama sends 560 credits to Gemini
# 💸 Gemini sends 100 credits to Llama
# 💸 ChatGPT sends 50 credits to Claude
# 💸 ChatGPT sends 40 credits to Qwen
# 💸 Qwen sends 45 credits to ChatGPT
#
# 💰 Transactions phase concluded
#
# 📊 Transaction Matrix - Round 10
# ╒════════════════╤══════════╤═════════╤══════════╤═══════════╤════════╕
# │      TO ↓      │  Claude  │  Llama  │  Gemini  │  ChatGPT  │  Qwen  │
# ╞════════════════╪══════════╪═════════╪══════════╪═══════════╪════════╡
# │ FROM Claude →  │    —     │   115   │    0     │     0     │   0    │
# ├────────────────┼──────────┼─────────┼──────────┼───────────┼────────┤
# │  FROM Llama →  │    0     │    —    │   560    │     0     │   0    │
# ├────────────────┼──────────┼─────────┼──────────┼───────────┼────────┤
# │ FROM Gemini →  │    0     │   100   │    —     │     0     │   0    │
# ├────────────────┼──────────┼─────────┼──────────┼───────────┼────────┤
# │ FROM ChatGPT → │    50    │    0    │    0     │     —     │   40   │
# ├────────────────┼──────────┼─────────┼──────────┼───────────┼────────┤
# │  FROM Qwen →   │    0     │    0    │    0     │    45     │   —    │
# ╘════════════════╧══════════╧═════════╧══════════╧═══════════╧════════╛
#
# 📈 Round Summary:
# ------------------  -----------
# Total Transactions  910 credits
# Active Players      5
# ------------------  -----------
# 🎁 Bonus applied between Llama and Gemini: 100 credits
# 🎁 Bonus applied between ChatGPT and Qwen: 40 credits
#
# 🏆 Current Rankings:
# ╒════════╤══════════╤══════════════╕
# │   Rank │  Player  │   Balance    │
# ╞════════╪══════════╪══════════════╡
# │      1 │  Gemini  │ 1220 credits │
# ├────────┼──────────┼──────────────┤
# │      2 │  Llama   │ 315 credits  │
# ├────────┼──────────┼──────────────┤
# │      3 │   Qwen   │ 130 credits  │
# ├────────┼──────────┼──────────────┤
# │      4 │ ChatGPT  │  85 credits  │
# ├────────┼──────────┼──────────────┤
# │      5 │  Claude  │  50 credits  │
# ╘════════╧══════════╧══════════════╛
# ──────────────────────────────────────────────────
# 🏁 GAME COMPLETED 🏁
# ──────────────────────────────────────────────────
#
# 📊 Final Results:
# ╒══════════╤══════════════╕
# │  Player  │   Balance    │
# ╞══════════╪══════════════╡
# │  Gemini  │ 1220 credits │
# ├──────────┼──────────────┤
# │  Llama   │ 315 credits  │
# ├──────────┼──────────────┤
# │   Qwen   │ 130 credits  │
# ├──────────┼──────────────┤
# │ ChatGPT  │  85 credits  │
# ├──────────┼──────────────┤
# │  Claude  │  50 credits  │
# ╘══════════╧══════════════╛
# {'Claude': 50, 'Llama': 315, 'Gemini': 1220, 'ChatGPT': 85, 'Qwen': 130}

# %%
from llmtournaments.games.credit_exchanges.base_objects import (
    GameConfig,
    LLMPlayer,
)
from llmtournaments.games.credit_exchanges.credit_exchanges_game import (
    CreditExchangeGame,
)
from llmtournaments.games.credit_exchanges.observers import ConsolePrinter
from llmtournaments.llm.generators.dummy_llm_03 import (
    DummyLLMInteractionForCreditExchanges,
)

num_players = 3
threshold = 500
initial_balance = 1000
rounds = 5

dummy_llmA = LLMPlayer(
    llm=DummyLLMInteractionForCreditExchanges("A", ["B", "C"], 10), name="A"
)
dummy_llmB = LLMPlayer(
    llm=DummyLLMInteractionForCreditExchanges("B", ["A", "C"], 10), name="B"
)
dummy_llmC = LLMPlayer(
    llm=DummyLLMInteractionForCreditExchanges("C", ["A", "B"], 10), name="C"
)

players = [dummy_llmA, dummy_llmB, dummy_llmC]

gc = GameConfig(4, 10, 3)
lo = ConsolePrinter()


game = CreditExchangeGame(players, gc)
game.add_observer(lo)
game.run_game()
